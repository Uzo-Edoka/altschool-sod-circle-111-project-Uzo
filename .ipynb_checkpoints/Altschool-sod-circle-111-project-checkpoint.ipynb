# %%
#We will be working with matplotlib

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
x = np.array([0,4])
y = np.array([4,10])

plt.plot(x, y)
plt.show()
